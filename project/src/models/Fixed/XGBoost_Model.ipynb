# %% [markdown]
# # XGBoost Model

# %% [markdown]
# ## Step 1: Import packages and set working directory

# %%
# Import packages
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import xgboost as xgb
import optuna

# %%
# Optional Code: Here's a format for setting working directory, change as needed
import os
# os.chdir('/path/to/the/project')
os.chdir('/Users/zihanji/Desktop/DS340W')

# %% [markdown]
# ## Step 2: Load the final cleaned data

# %%
data_final = pd.read_csv('./project/volume/data/processed/data_final.csv')

# %% [markdown]
# ## Step 3: Building the XGBoost model

# %%
# Split the data to features and result
x = data_final.drop('SalePrice', axis = 1)
y = data_final['SalePrice']

# %%
# Split the data to train and test, with test size being 20% of the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Fit the model to built a prediction for x test
XGBoost = xgb.XGBRegressor()
XGBoost.fit(x_train, y_train)
XGBoost_pred = XGBoost.predict(x_test)

# %% [markdown]
# ## Step 4: Check for scores

# %%
# Check for the score of the prediction
XGBoost_score = XGBoost.score(x_train, y_train)
print('XGBoost Model Score: ', round(XGBoost_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(XGBoost, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.998
# R Squared:  0.916
# Adjusted R Squared:  0.908
# Mean Squared Error:  0.015
# Root Mean Squared Error:  0.124
# Mean Absolute Error:  0.087
# Accuracy:  89.145 %

# %% [markdown]
# ## Step 5: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 6: Hyperparameter tuning (grid search)

# %%
# Specifies hyperparameter options
parameters = {'objective': ['reg:squarederror', 'reg:linear'], 'min_child_weight': [1, 2], 'gamma': [0.5, 1],
              'subsample': [0.2, 0.4], 'max_depth': [1, 2]}

# %%
# Apply grid search to find the best hyperparameter option
GS_CV_xgb = GridSearchCV(estimator = XGBoost, param_grid = parameters, cv = 5)
GS_CV_xgb.fit(x_train, y_train)
GS_CV_xgb.best_params_
# Return: {}
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:14] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:17] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:17] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:17] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:20] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:20] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:20] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:21] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:21] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:24] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:24] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:24] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:24] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:24] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:27] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/xgboost/training.py:183: UserWarning: [22:47:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# {'gamma': 0.5,
#  'max_depth': 2,
#  'min_child_weight': 1,
#  'objective': 'reg:squarederror',
#  'subsample': 0.4}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 1, 'objective': 'reg:squarederror', 'subsample': 0.4}
XGBoost_mod = xgb.XGBRegressor(objective = 'reg:squarederror', max_depth = 2, gamma = 0.5, min_child_weight = 1,
                               subsample = 0.4)
XGBoost_mod.fit(x_train, y_train)
XGBoost_pred = XGBoost_mod.predict(x_test)

# %% [markdown]
# ## Step 7: Check for scores

# %%
# Check for the score of the prediction
XGBoost_mod_score = XGBoost_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(XGBoost_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(XGBoost_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.897
# R Squared:  0.894
# Adjusted R Squared:  0.883
# Mean Squared Error:  0.02
# Root Mean Squared Error:  0.14
# Mean Absolute Error:  0.099
# Accuracy:  87.26 %

# %% [markdown]
# ## Step 8: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 9: Check feature important

# %%
feature_important = XGBoost_mod.get_booster().get_score(importance_type = 'total_gain')
# Extract the feature names and scores
keys = list(feature_important.keys())
values = list(feature_important.values())
# Create a dataframe
data = pd.DataFrame(data = values, index = keys, columns = ['score']).sort_values(by = 'score', ascending = True)
# Plot the top 10 features
data.nlargest(10, columns = 'score').plot(kind = 'barh', figsize = (10, 15))
# Out:
# <Axes: >

# %% [markdown]
# ## Step 10: Hyperparameter tuning (optuna, with the same hyperparamter space as grid search)

# %%
def objective(trial):
    # Define hyperparameter search space
    parameters = {'objective': 'reg:squarederror',
                  'min_child_weight': trial.suggest_int('min_child_weight', 1,2),
                  'gamma': trial.suggest_int('gamma', 0.5, 1),
                  'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
                  'max_depth': trial.suggest_int('max_depth', 3, 9)}
    # Train xgboost model
    model = xgb.XGBRegressor(**parameters)
    model.fit(x_train, y_train, eval_set = [(x_test, y_test)],  verbose = False)
    # Evaluate model
    predict = model.predict(x_test)
    mse = mean_squared_error(y_test, predict)
    rmse = np.sqrt(mse)
    return rmse

# %%
# Run optuna optimization
study = optuna.create_study(direction = 'minimize')  # Minimize RMSE
study.optimize(objective, n_trials = 50)

# Print best hyperparameters
print('Best RMSE: ', study.best_value)
print('Best Hyperparameters: ', study.best_params)
# Out:
# [I 2025-04-10 22:47:57,940] A new study created in memory with name: no-name-2bedefae-3498-410e-a0ac-098e91d5a69a
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:58,186] Trial 0 finished with value: 0.13658676352255278 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.6135749137699384, 'max_depth': 6}. Best is trial 0 with value: 0.13658676352255278.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:58,414] Trial 1 finished with value: 0.13446424495306936 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.6326896259062276, 'max_depth': 7}. Best is trial 1 with value: 0.13446424495306936.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:58,637] Trial 2 finished with value: 0.1344219455025845 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.5837799090201652, 'max_depth': 3}. Best is trial 2 with value: 0.1344219455025845.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:58,863] Trial 3 finished with value: 0.13312367871752143 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.9384579418373808, 'max_depth': 9}. Best is trial 3 with value: 0.13312367871752143.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:59,093] Trial 4 finished with value: 0.12698030441515296 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.97664431609972, 'max_depth': 6}. Best is trial 4 with value: 0.12698030441515296.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:59,412] Trial 5 finished with value: 0.11750588931346208 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.5370018054311024, 'max_depth': 3}. Best is trial 5 with value: 0.11750588931346208.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:59,701] Trial 6 finished with value: 0.11794329134707661 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.5408127032341448, 'max_depth': 3}. Best is trial 5 with value: 0.11750588931346208.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:47:59,987] Trial 7 finished with value: 0.129277469000161 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.7740496150821381, 'max_depth': 9}. Best is trial 5 with value: 0.11750588931346208.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:00,627] Trial 8 finished with value: 0.12261049736615147 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.816442818570015, 'max_depth': 7}. Best is trial 5 with value: 0.11750588931346208.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:01,140] Trial 9 finished with value: 0.11973526338425546 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.8209831252773341, 'max_depth': 7}. Best is trial 5 with value: 0.11750588931346208.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:01,474] Trial 10 finished with value: 0.11402433865914571 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6983876506616846, 'max_depth': 4}. Best is trial 10 with value: 0.11402433865914571.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:01,828] Trial 11 finished with value: 0.11585418013297882 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6982184919796901, 'max_depth': 4}. Best is trial 10 with value: 0.11402433865914571.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:02,192] Trial 12 finished with value: 0.12334066548819317 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.672895267514719, 'max_depth': 5}. Best is trial 10 with value: 0.11402433865914571.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:02,509] Trial 13 finished with value: 0.11234582442318344 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6990275510760654, 'max_depth': 4}. Best is trial 13 with value: 0.11234582442318344.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:02,827] Trial 14 finished with value: 0.11601235333597738 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7278411531898097, 'max_depth': 4}. Best is trial 13 with value: 0.11234582442318344.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:03,190] Trial 15 finished with value: 0.11972119272388944 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8920925775953121, 'max_depth': 5}. Best is trial 13 with value: 0.11234582442318344.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:03,509] Trial 16 finished with value: 0.1084847075567906 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7719762012876137, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:03,873] Trial 17 finished with value: 0.12024636265061318 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.782270200949758, 'max_depth': 5}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:04,189] Trial 18 finished with value: 0.11938942483209622 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8292324154958374, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:04,671] Trial 19 finished with value: 0.12266836850349716 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8797906602386639, 'max_depth': 6}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:05,031] Trial 20 finished with value: 0.1179833793272777 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.743873769287123, 'max_depth': 5}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:05,355] Trial 21 finished with value: 0.11589183465035009 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6773365653373609, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:05,676] Trial 22 finished with value: 0.12026240439149039 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7047592815796174, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:05,960] Trial 23 finished with value: 0.12050327457757334 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6365806119227511, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:06,317] Trial 24 finished with value: 0.12123897826221837 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7698450643044465, 'max_depth': 5}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:06,645] Trial 25 finished with value: 0.1146411783398006 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6643068674176333, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:06,929] Trial 26 finished with value: 0.11337500352162821 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.741815984377936, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:07,221] Trial 27 finished with value: 0.11521039788247651 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8692656011862555, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:07,516] Trial 28 finished with value: 0.11543412882078079 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.737483860823441, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:07,753] Trial 29 finished with value: 0.13252431098930395 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.5895962797204205, 'max_depth': 8}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:08,111] Trial 30 finished with value: 0.11606883330253119 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8034108793285883, 'max_depth': 5}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:08,432] Trial 31 finished with value: 0.11928812157044523 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7066516775537856, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:08,752] Trial 32 finished with value: 0.12381448706245203 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6513294757398538, 'max_depth': 4}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:09,038] Trial 33 finished with value: 0.11087002227896349 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7530058111831338, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:09,276] Trial 34 finished with value: 0.13504509267561357 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.8473624283865121, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:09,564] Trial 35 finished with value: 0.11593924284643341 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6068930038362563, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:09,795] Trial 36 finished with value: 0.13672256581711134 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.7626928335880077, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:10,104] Trial 37 finished with value: 0.1111223429011829 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9195727533764437, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:10,406] Trial 38 finished with value: 0.11273664099196035 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9890113116602683, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:10,642] Trial 39 finished with value: 0.13515780452391243 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.9293502951312703, 'max_depth': 6}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:11,145] Trial 40 finished with value: 0.12425942201518644 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.5055795879576509, 'max_depth': 8}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:11,437] Trial 41 finished with value: 0.11244757242684383 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9914698903370195, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:11,723] Trial 42 finished with value: 0.11115286877578706 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9454396976338788, 'max_depth': 3}. Best is trial 16 with value: 0.1084847075567906.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:12,009] Trial 43 finished with value: 0.10696730818750216 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9270909405400154, 'max_depth': 3}. Best is trial 43 with value: 0.10696730818750216.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:12,295] Trial 44 finished with value: 0.11335000904587177 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9578615885697158, 'max_depth': 3}. Best is trial 43 with value: 0.10696730818750216.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:12,582] Trial 45 finished with value: 0.10457856673960331 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9325037647594885, 'max_depth': 3}. Best is trial 45 with value: 0.10457856673960331.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:12,860] Trial 46 finished with value: 0.11593054366607393 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8968540887988424, 'max_depth': 3}. Best is trial 45 with value: 0.10457856673960331.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:13,180] Trial 47 finished with value: 0.11145472026411202 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9199746818470731, 'max_depth': 4}. Best is trial 45 with value: 0.10457856673960331.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:13,469] Trial 48 finished with value: 0.10816124958762084 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9647131811614126, 'max_depth': 3}. Best is trial 45 with value: 0.10457856673960331.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2792355205.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-10 22:48:13,786] Trial 49 finished with value: 0.1148596373317088 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9745835930872344, 'max_depth': 4}. Best is trial 45 with value: 0.10457856673960331.
# Best RMSE:  0.10457856673960331
# Best Hyperparameters:  {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9325037647594885, 'max_depth': 3}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9325037647594885, 'max_depth': 3}
xgb_mod = xgb.XGBRegressor(objective = 'reg:squarederror', max_depth = 3, gamma = 0, min_child_weight = 2, 
                           subsample = 0.9325037647594885)
xgb_mod.fit(x_train, y_train)
XGBoost_pred = xgb_mod.predict(x_test)

# %% [markdown]
# ## Step 11: Check for scores

# %%
# Check for the score of the prediction
xgb_mod_score = xgb_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(xgb_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(xgb_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.965
# R Squared:  0.941
# Adjusted R Squared:  0.935
# Mean Squared Error:  0.011
# Root Mean Squared Error:  0.105
# Mean Absolute Error:  0.076
# Accuracy:  89.513 %

# %% [markdown]
# ## Step 12: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 13: Hyperparameter tuning (optuna, with bigger hyperparamter space)

# %%
def objective(trial):
    # Define hyperparameter search space
    parameters = {'objective': 'reg:squarederror',
                  'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
                  'gamma': trial.suggest_int('gamma', 0.1, 1),
                  'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
                  'max_depth': trial.suggest_int('max_depth', 1, 20),
                  'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step = 100),
                  'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
                  'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
    # Train xgboost model
    model = xgb.XGBRegressor(**parameters)
    model.fit(x_train, y_train, eval_set = [(x_test, y_test)],  verbose = False)
    # Evaluate model
    predict = model.predict(x_test)
    mse = mean_squared_error(y_test, predict)
    rmse = np.sqrt(mse)
    return rmse

# %%
# Run optuna optimization
study = optuna.create_study(direction = 'minimize')  # Minimize RMSE
study.optimize(objective, n_trials = 50)

# Print best hyperparameters
print('Best RMSE: ', study.best_value)
print('Best Hyperparameters: ', study.best_params)
# Out:
# [I 2025-04-10 22:48:52,633] A new study created in memory with name: no-name-d1719ca4-57f6-4323-a673-7568c657e451
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:53,009] Trial 0 finished with value: 0.17984915737240492 and parameters: {'min_child_weight': 11, 'gamma': 1, 'subsample': 0.8947414389040887, 'max_depth': 16, 'n_estimators': 200, 'learning_rate': 0.8560157576554078, 'colsample_bytree': 0.2081057207593423}. Best is trial 0 with value: 0.17984915737240492.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:53,373] Trial 1 finished with value: 0.1440435501234955 and parameters: {'min_child_weight': 4, 'gamma': 1, 'subsample': 0.7233226365552257, 'max_depth': 16, 'n_estimators': 200, 'learning_rate': 0.5286800414114081, 'colsample_bytree': 0.818480116807652}. Best is trial 1 with value: 0.1440435501234955.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:55,683] Trial 2 finished with value: 0.2650065596949905 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.5972521290767708, 'max_depth': 14, 'n_estimators': 500, 'learning_rate': 0.8578095404038417, 'colsample_bytree': 0.07088801650453203}. Best is trial 1 with value: 0.1440435501234955.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:57,047] Trial 3 finished with value: 0.14367826171365966 and parameters: {'min_child_weight': 8, 'gamma': 1, 'subsample': 0.5777047355524706, 'max_depth': 12, 'n_estimators': 800, 'learning_rate': 0.5824100616128505, 'colsample_bytree': 0.8581692905781795}. Best is trial 3 with value: 0.14367826171365966.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:57,802] Trial 4 finished with value: 0.12802819172267343 and parameters: {'min_child_weight': 12, 'gamma': 1, 'subsample': 0.8358304104266202, 'max_depth': 20, 'n_estimators': 400, 'learning_rate': 0.04701867701750018, 'colsample_bytree': 0.5453579439039046}. Best is trial 4 with value: 0.12802819172267343.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:58,325] Trial 5 finished with value: 0.13305084121489769 and parameters: {'min_child_weight': 10, 'gamma': 1, 'subsample': 0.6938471767569127, 'max_depth': 2, 'n_estimators': 300, 'learning_rate': 0.10227654064708858, 'colsample_bytree': 0.3677309865744657}. Best is trial 4 with value: 0.12802819172267343.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:48:59,381] Trial 6 finished with value: 0.17791098406317044 and parameters: {'min_child_weight': 19, 'gamma': 1, 'subsample': 0.13211953969189447, 'max_depth': 19, 'n_estimators': 700, 'learning_rate': 0.8844848770967259, 'colsample_bytree': 0.4602179245386071}. Best is trial 4 with value: 0.12802819172267343.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:00,166] Trial 7 finished with value: 0.12709965737051637 and parameters: {'min_child_weight': 10, 'gamma': 1, 'subsample': 0.5256392136247635, 'max_depth': 3, 'n_estimators': 500, 'learning_rate': 0.14437685105836295, 'colsample_bytree': 0.23317338470007565}. Best is trial 7 with value: 0.12709965737051637.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:02,221] Trial 8 finished with value: 0.11653714305890603 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6090024767445464, 'max_depth': 5, 'n_estimators': 800, 'learning_rate': 0.166491338629522, 'colsample_bytree': 0.08620718483177636}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:03,324] Trial 9 finished with value: 0.12140590362930628 and parameters: {'min_child_weight': 6, 'gamma': 0, 'subsample': 0.767535791131463, 'max_depth': 5, 'n_estimators': 500, 'learning_rate': 0.13022862684159647, 'colsample_bytree': 0.0120055643228969}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:06,841] Trial 10 finished with value: 0.16561897254779648 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.23364562740610523, 'max_depth': 7, 'n_estimators': 1000, 'learning_rate': 0.3143402497770078, 'colsample_bytree': 0.6830181079239883}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:08,815] Trial 11 finished with value: 0.15259336479231045 and parameters: {'min_child_weight': 5, 'gamma': 0, 'subsample': 0.34470777409799025, 'max_depth': 7, 'n_estimators': 700, 'learning_rate': 0.30251386379585826, 'colsample_bytree': 0.02871984130034977}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:11,428] Trial 12 finished with value: 0.1343017089484251 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.3989694399654392, 'max_depth': 5, 'n_estimators': 1000, 'learning_rate': 0.2978859210455512, 'colsample_bytree': 0.1773497421416777}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:13,836] Trial 13 finished with value: 0.12489348300538544 and parameters: {'min_child_weight': 6, 'gamma': 0, 'subsample': 0.7641354278879885, 'max_depth': 8, 'n_estimators': 800, 'learning_rate': 0.22560178014823365, 'colsample_bytree': 0.029003054647896653}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:15,111] Trial 14 finished with value: 0.13686166898290347 and parameters: {'min_child_weight': 3, 'gamma': 0, 'subsample': 0.9495391330375444, 'max_depth': 10, 'n_estimators': 600, 'learning_rate': 0.4257294266887671, 'colsample_bytree': 0.3599769769340868}. Best is trial 8 with value: 0.11653714305890603.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:16,536] Trial 15 finished with value: 0.11613041716877756 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.9935035519643394, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.7131989078734363, 'colsample_bytree': 0.14584535200315868}. Best is trial 15 with value: 0.11613041716877756.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:17,972] Trial 16 finished with value: 0.11650341212701074 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.9935671206542168, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.6857634980990488, 'colsample_bytree': 0.9789615181416389}. Best is trial 15 with value: 0.11613041716877756.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:19,442] Trial 17 finished with value: 0.1155817313786927 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.9785549486184474, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.6876215606554746, 'colsample_bytree': 0.9748090962240834}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:20,839] Trial 18 finished with value: 0.11819722042731468 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.8602987130346548, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.6890797061545926, 'colsample_bytree': 0.6321148969599089}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:22,992] Trial 19 finished with value: 0.15553636513218705 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.9986896223340973, 'max_depth': 3, 'n_estimators': 1000, 'learning_rate': 0.9954400193147276, 'colsample_bytree': 0.9992993615626574}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:24,769] Trial 20 finished with value: 0.15225083005011844 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.875210135647683, 'max_depth': 9, 'n_estimators': 700, 'learning_rate': 0.6231706111502069, 'colsample_bytree': 0.7592762312987418}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:26,196] Trial 21 finished with value: 0.11650295813549665 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.9865119705125559, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.7297435385691149, 'colsample_bytree': 0.983420546396035}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:28,393] Trial 22 finished with value: 0.14396163422939473 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.9325612594572477, 'max_depth': 4, 'n_estimators': 900, 'learning_rate': 0.7213559230695795, 'colsample_bytree': 0.9084936367743468}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:29,851] Trial 23 finished with value: 0.11968596637430094 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.8078250885441993, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.7451283812769048, 'colsample_bytree': 0.7562229553390265}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:31,566] Trial 24 finished with value: 0.12078885696512173 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.9222758331465093, 'max_depth': 3, 'n_estimators': 800, 'learning_rate': 0.46359553053796454, 'colsample_bytree': 0.9164237168748472}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:33,416] Trial 25 finished with value: 0.19746647292669203 and parameters: {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.6752495736494469, 'max_depth': 6, 'n_estimators': 600, 'learning_rate': 0.8168129210892713, 'colsample_bytree': 0.5561460993175393}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:34,955] Trial 26 finished with value: 0.11588808722975123 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.9824132532535217, 'max_depth': 1, 'n_estimators': 1000, 'learning_rate': 0.9615476349103041, 'colsample_bytree': 0.3804130650138323}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:37,035] Trial 27 finished with value: 0.3963562543239137 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.4256949666583123, 'max_depth': 3, 'n_estimators': 1000, 'learning_rate': 0.9473809931795228, 'colsample_bytree': 0.305281443283886}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:39,465] Trial 28 finished with value: 0.14675565398826645 and parameters: {'min_child_weight': 12, 'gamma': 0, 'subsample': 0.8246509699750143, 'max_depth': 12, 'n_estimators': 1000, 'learning_rate': 0.6189610621015457, 'colsample_bytree': 0.43678563558717465}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:41,130] Trial 29 finished with value: 0.16643335961862182 and parameters: {'min_child_weight': 9, 'gamma': 0, 'subsample': 0.9044836104443308, 'max_depth': 4, 'n_estimators': 700, 'learning_rate': 0.773095649539019, 'colsample_bytree': 0.1667551192691672}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:42,574] Trial 30 finished with value: 5559.955412677273 and parameters: {'min_child_weight': 12, 'gamma': 0, 'subsample': 0.05301827116661706, 'max_depth': 2, 'n_estimators': 800, 'learning_rate': 0.9151657106513666, 'colsample_bytree': 0.252120991498271}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:43,968] Trial 31 finished with value: 0.11597657275162455 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.9985822959536725, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.8158989304624829, 'colsample_bytree': 0.6618163838512946}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:45,634] Trial 32 finished with value: 0.13503045208936404 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.9097447754567669, 'max_depth': 2, 'n_estimators': 900, 'learning_rate': 0.8064561584265564, 'colsample_bytree': 0.6436629538407856}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:45,871] Trial 33 finished with value: 0.12926426837435126 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.946892633723858, 'max_depth': 1, 'n_estimators': 100, 'learning_rate': 0.9803108253720734, 'colsample_bytree': 0.11923890316016617}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:47,928] Trial 34 finished with value: 0.14243410762712977 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.9999051920138913, 'max_depth': 3, 'n_estimators': 1000, 'learning_rate': 0.8511391099379296, 'colsample_bytree': 0.40500809056378195}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
# ...
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:53,475] Trial 38 finished with value: 0.14840579746505173 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.7111825793832955, 'max_depth': 2, 'n_estimators': 1000, 'learning_rate': 0.8462704064205907, 'colsample_bytree': 0.6040471681894466}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:54,691] Trial 39 finished with value: 0.16335019308924914 and parameters: {'min_child_weight': 17, 'gamma': 1, 'subsample': 0.9515580111884843, 'max_depth': 2, 'n_estimators': 800, 'learning_rate': 0.7869749595450312, 'colsample_bytree': 0.6919657719576919}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:56,381] Trial 40 finished with value: 0.13227902254436638 and parameters: {'min_child_weight': 8, 'gamma': 0, 'subsample': 0.8825661869803441, 'max_depth': 6, 'n_estimators': 600, 'learning_rate': 0.48853044709824467, 'colsample_bytree': 0.4974010725396617}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:57,823] Trial 41 finished with value: 0.11793559555059126 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.9591762610851148, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.7438774689727679, 'colsample_bytree': 0.8980180856305304}. Best is trial 17 with value: 0.1155817313786927.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:49:59,254] Trial 42 finished with value: 0.11509260339443382 and parameters: {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.9997251525104132, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.5925700955713402, 'colsample_bytree': 0.8448906647214084}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:01,689] Trial 43 finished with value: 0.13916730666466545 and parameters: {'min_child_weight': 19, 'gamma': 0, 'subsample': 0.8932618661070114, 'max_depth': 4, 'n_estimators': 1000, 'learning_rate': 0.5420886803628859, 'colsample_bytree': 0.8237930551235554}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:02,992] Trial 44 finished with value: 0.13621052856268062 and parameters: {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.8088117285732462, 'max_depth': 2, 'n_estimators': 700, 'learning_rate': 0.6028546204079198, 'colsample_bytree': 0.8712638229943224}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:04,116] Trial 45 finished with value: 0.14806629096796928 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.8413703411445831, 'max_depth': 5, 'n_estimators': 400, 'learning_rate': 0.657598030815432, 'colsample_bytree': 0.7109370168787372}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:06,805] Trial 46 finished with value: 0.13580397017503923 and parameters: {'min_child_weight': 19, 'gamma': 0, 'subsample': 0.9596044559616899, 'max_depth': 18, 'n_estimators': 900, 'learning_rate': 0.4182363611691255, 'colsample_bytree': 0.800376409847519}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:08,526] Trial 47 finished with value: 0.21414161787300898 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.5436124324520094, 'max_depth': 3, 'n_estimators': 800, 'learning_rate': 0.8643848600089774, 'colsample_bytree': 0.5852537721263675}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:10,091] Trial 48 finished with value: 0.12096787027343485 and parameters: {'min_child_weight': 12, 'gamma': 0, 'subsample': 0.7356295463720885, 'max_depth': 1, 'n_estimators': 1000, 'learning_rate': 0.565293994047708, 'colsample_bytree': 0.9481107502019451}. Best is trial 42 with value: 0.11509260339443382.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_30429/2739641617.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-10 22:50:11,434] Trial 49 finished with value: 0.16865188861510574 and parameters: {'min_child_weight': 10, 'gamma': 1, 'subsample': 0.9209185608909156, 'max_depth': 6, 'n_estimators': 900, 'learning_rate': 0.9081873903939801, 'colsample_bytree': 0.8551785669189917}. Best is trial 42 with value: 0.11509260339443382.
# Best RMSE:  0.11509260339443382
# Best Hyperparameters:  {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.9997251525104132, 'max_depth': 1, 'n_estimators': 900, 'learning_rate': 0.5925700955713402, 'colsample_bytree': 0.8448906647214084}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.9997251525104132, 'max_depth': 1, 'n_estimators': 900, 
# 'learning_rate': 0.5925700955713402, 'colsample_bytree': 0.8448906647214084}
xgboost_mod = xgb.XGBRegressor(objective = 'reg:squarederror', min_child_weight = 17, gamma = 0, 
                               subsample = 0.9997251525104132, max_depth = 1, n_estimators = 900, 
                               learning_rate = 0.5925700955713402, colsample_bytree = 0.8448906647214084)
xgboost_mod.fit(x_train, y_train)
XGBoost_pred = xgboost_mod.predict(x_test)

# %% [markdown]
# ## Step 14: Check for scores

# %%
# Check for the score of the prediction
xgboost_mod_score = xgboost_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(xgboost_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(xgboost_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.938
# R Squared:  0.928
# Adjusted R Squared:  0.921
# Mean Squared Error:  0.013
# Root Mean Squared Error:  0.115
# Mean Absolute Error:  0.079
# Accuracy:  90.137 %

# %% [markdown]
# ## Step 15: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 16: Check feature important

# %%
feature_important = xgboost_mod.get_booster().get_score(importance_type = 'total_gain')
# Extract the feature names and scores
keys = list(feature_important.keys())
values = list(feature_important.values())
# Create a dataframe
data = pd.DataFrame(data = values, index = keys, columns = ['score']).sort_values(by = 'score', ascending = True)
# Plot the top 10 features
data.nlargest(10, columns = 'score').plot(kind = 'barh', figsize = (7, 6), title = "XGBoost Feature Importance")
# Out:
# <Axes: title={'center': 'XGBoost Feature Importance'}>
