# %% [markdown]
# # XGBoost Model

# %% [markdown]
# ## Step 1: Import packages and set working directory

# %%
# Import packages
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import xgboost as xgb
import optuna

# %%
# Optional Code: Here's a format for setting working directory, change as needed
import os
# os.chdir('/path/to/the/project')
os.chdir('/Users/zihanji/Desktop/DS340W')

# %% [markdown]
# ## Step 2: Load the final cleaned data

# %%
data_final = pd.read_csv('./project/volume/data/processed/data_final.csv')

# %% [markdown]
# ## Step 3: Building the XGBoost model

# %%
# Split the data to features and result
x = data_final.drop('SalePrice', axis = 1)
y = data_final['SalePrice']

# %%
# Split the data to train and test, with test size being 20% of the data
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
# Fit the model to built a prediction for x test
XGBoost = xgb.XGBRegressor()
XGBoost.fit(x_train, y_train)
XGBoost_pred = XGBoost.predict(x_test)

# %% [markdown]
# ## Step 4: Check for scores

# %%
# Check for the score of the prediction
XGBoost_score = XGBoost.score(x_train, y_train)
print('XGBoost Model Score: ', round(XGBoost_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(XGBoost, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.998
# R Squared:  0.916
# Adjusted R Squared:  0.908
# Mean Squared Error:  0.015
# Root Mean Squared Error:  0.124
# Mean Absolute Error:  0.087
# Accuracy:  89.145 %

# %% [markdown]
# ## Step 5: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 6: Hyperparameter tuning (grid search)

# %%
# Specifies hyperparameter options
parameters = {'objective': ['reg:squarederror', 'reg:linear'], 'min_child_weight': [1, 2], 'gamma': [0.5, 1],
              'subsample': [0.2, 0.4], 'max_depth': [1, 2]}

# %%
# Apply grid search to find the best hyperparameter option
GS_CV_xgb = GridSearchCV(estimator = XGBoost, param_grid = parameters, cv = 5)
GS_CV_xgb.fit(x_train, y_train)
GS_CV_xgb.best_params_
# Return: {}
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:08] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:08] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:09] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:10] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:11] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:12] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:13] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:15] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:16] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:18] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:19] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:20] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:21] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:22] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:23] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:23] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:23] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:25] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:26] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:26] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:26] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:26] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:28] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:29] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:31] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:32] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/xgboost/training.py:183: UserWarning: [18:30:33] WARNING: /Users/runner/work/xgboost/xgboost/src/objective/regression_obj.cu:250: reg:linear is now deprecated in favor of reg:squarederror.
#   bst.update(dtrain, iteration=i, fobj=obj)
# {'gamma': 0.5,
#  'max_depth': 2,
#  'min_child_weight': 1,
#  'objective': 'reg:squarederror',
#  'subsample': 0.4}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'gamma': 0.5, 'max_depth': 2, 'min_child_weight': 1, 'objective': 'reg:squarederror', 'subsample': 0.4}
XGBoost_mod = xgb.XGBRegressor(objective = 'reg:squarederror', max_depth = 2, gamma = 0.5, min_child_weight = 1,
                               subsample = 0.4)
XGBoost_mod.fit(x_train, y_train)
XGBoost_pred = XGBoost_mod.predict(x_test)

# %% [markdown]
# ## Step 7: Check for scores

# %%
# Check for the score of the prediction
XGBoost_mod_score = XGBoost_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(XGBoost_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(XGBoost_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.897
# R Squared:  0.894
# Adjusted R Squared:  0.883
# Mean Squared Error:  0.02
# Root Mean Squared Error:  0.14
# Mean Absolute Error:  0.099
# Accuracy:  87.26 %

# %% [markdown]
# ## Step 8: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 9: Check feature important

# %%
feature_important = XGBoost_mod.get_booster().get_score(importance_type = 'total_gain')
# Extract the feature names and scores
keys = list(feature_important.keys())
values = list(feature_important.values())
# Create a dataframe
data = pd.DataFrame(data = values, index = keys, columns = ['score']).sort_values(by = 'score', ascending = True)
# Plot the top 10 features
data.nlargest(10, columns = 'score').plot(kind = 'barh', figsize = (10, 15))
# Out:
# <Axes: >

# %% [markdown]
# ## Step 10: Hyperparameter tuning (optuna, with the same hyperparamter space as grid search)

# %%
def objective(trial):
    # Define hyperparameter search space
    parameters = {'objective': 'reg:squarederror',
             'min_child_weight': trial.suggest_int('min_child_weight', 1,2),
             'gamma': trial.suggest_int('gamma', 0.5, 1),
             'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
             'max_depth': trial.suggest_int('max_depth', 3, 9)}
    # Train xgboost model
    model = xgb.XGBRegressor(**parameters)
    model.fit(x_train, y_train, eval_set = [(x_test, y_test)],  verbose = False)
    # Evaluate model
    predict = model.predict(x_test)
    mse = mean_squared_error(y_test, predict)
    rmse = np.sqrt(mse)
    return rmse

# %%
# Run optuna optimization
study = optuna.create_study(direction = 'minimize')  # Minimize RMSE
study.optimize(objective, n_trials = 50)

# Print best hyperparameters
print('Best RMSE: ', study.best_value)
print('Best Hyperparameters: ', study.best_params)
# Out:
# [I 2025-04-05 18:33:33,483] A new study created in memory with name: no-name-1ae9b849-dffa-451e-b151-b4394757f3d5
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:33,756] Trial 0 finished with value: 0.12954180379358282 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.879503559630413, 'max_depth': 7}. Best is trial 0 with value: 0.12954180379358282.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:34,048] Trial 1 finished with value: 0.13857374762861058 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.6122882028779663, 'max_depth': 7}. Best is trial 0 with value: 0.12954180379358282.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:34,335] Trial 2 finished with value: 0.1424021235883123 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.5196676273657244, 'max_depth': 4}. Best is trial 0 with value: 0.12954180379358282.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:34,766] Trial 3 finished with value: 0.11951039947493759 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.6494040622857333, 'max_depth': 5}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:35,536] Trial 4 finished with value: 0.12738591160099347 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.8461080241299488, 'max_depth': 9}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:35,855] Trial 5 finished with value: 0.1277286850736965 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.7993569224469859, 'max_depth': 9}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:36,130] Trial 6 finished with value: 0.13441031986177485 and parameters: {'min_child_weight': 1, 'gamma': 1, 'subsample': 0.591365033002107, 'max_depth': 3}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:36,404] Trial 7 finished with value: 0.1350622527503119 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.6512099489024938, 'max_depth': 7}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:36,693] Trial 8 finished with value: 0.13129464745354 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.8716970368633099, 'max_depth': 7}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:36,980] Trial 9 finished with value: 0.13081376456175575 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.5496545098423334, 'max_depth': 9}. Best is trial 3 with value: 0.11951039947493759.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:37,448] Trial 10 finished with value: 0.11941456228265117 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9902488979576858, 'max_depth': 5}. Best is trial 10 with value: 0.11941456228265117.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:37,896] Trial 11 finished with value: 0.11379595512126803 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9584402936924475, 'max_depth': 5}. Best is trial 11 with value: 0.11379595512126803.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:38,335] Trial 12 finished with value: 0.11352278146296035 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9744249838242927, 'max_depth': 5}. Best is trial 12 with value: 0.11352278146296035.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:38,726] Trial 13 finished with value: 0.11462622600784382 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9914288753365981, 'max_depth': 5}. Best is trial 12 with value: 0.11352278146296035.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:39,046] Trial 14 finished with value: 0.11068196303728851 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9351998866429915, 'max_depth': 3}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:39,368] Trial 15 finished with value: 0.11623812401194493 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7325057762856604, 'max_depth': 3}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:39,723] Trial 16 finished with value: 0.11213931035811481 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9293082207860841, 'max_depth': 4}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:40,043] Trial 17 finished with value: 0.11526435950754588 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.899527723157697, 'max_depth': 3}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:40,404] Trial 18 finished with value: 0.11952621576344206 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7481976470081616, 'max_depth': 4}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:40,757] Trial 19 finished with value: 0.11192546010316617 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9252023404668321, 'max_depth': 4}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:41,213] Trial 20 finished with value: 0.12162964705316344 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.8143546116964258, 'max_depth': 6}. Best is trial 14 with value: 0.11068196303728851.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:41,567] Trial 21 finished with value: 0.10982337053032308 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9269615644181872, 'max_depth': 4}. Best is trial 21 with value: 0.10982337053032308.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:41,920] Trial 22 finished with value: 0.11532606324836799 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9219702937009009, 'max_depth': 4}. Best is trial 21 with value: 0.10982337053032308.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:42,248] Trial 23 finished with value: 0.11667588265314431 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7983245380135099, 'max_depth': 3}. Best is trial 21 with value: 0.10982337053032308.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:42,605] Trial 24 finished with value: 0.11115877852092136 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9396700918591628, 'max_depth': 4}. Best is trial 21 with value: 0.10982337053032308.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:43,048] Trial 25 finished with value: 0.11480582449788085 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8350291077041039, 'max_depth': 6}. Best is trial 21 with value: 0.10982337053032308.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:43,368] Trial 26 finished with value: 0.10770269810379861 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9496818544914014, 'max_depth': 3}. Best is trial 26 with value: 0.10770269810379861.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:43,688] Trial 27 finished with value: 0.11435671228179524 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.7031748702742268, 'max_depth': 3}. Best is trial 26 with value: 0.10770269810379861.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:44,009] Trial 28 finished with value: 0.114956612335426 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8864902992155039, 'max_depth': 3}. Best is trial 26 with value: 0.10770269810379861.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:44,639] Trial 29 finished with value: 0.12383153063077629 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8671224231386252, 'max_depth': 8}. Best is trial 26 with value: 0.10770269810379861.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:45,006] Trial 30 finished with value: 0.10613011448512218 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9537488207626437, 'max_depth': 3}. Best is trial 30 with value: 0.10613011448512218.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:45,328] Trial 31 finished with value: 0.10957257098534251 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9612577008890921, 'max_depth': 3}. Best is trial 30 with value: 0.10613011448512218.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:45,654] Trial 32 finished with value: 0.10805572346914159 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9639641033073986, 'max_depth': 3}. Best is trial 30 with value: 0.10613011448512218.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:45,976] Trial 33 finished with value: 0.10822361790743584 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9644510540185462, 'max_depth': 3}. Best is trial 30 with value: 0.10613011448512218.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:46,297] Trial 34 finished with value: 0.11488495660606154 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9048512248877182, 'max_depth': 3}. Best is trial 30 with value: 0.10613011448512218.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:46,658] Trial 35 finished with value: 0.10515475152878133 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9957577759157695, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:47,018] Trial 36 finished with value: 0.10958436916276322 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.9920423590747368, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:47,456] Trial 37 finished with value: 0.1163658293812507 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9994448138314801, 'max_depth': 6}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:47,727] Trial 38 finished with value: 0.13079230801745967 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.8458591605958764, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:48,049] Trial 39 finished with value: 0.11389580244551252 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.9461149449694107, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:48,317] Trial 40 finished with value: 0.12700565309968165 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.8978298293140818, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:48,640] Trial 41 finished with value: 0.11123720092414743 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9679441766095599, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:48,961] Trial 42 finished with value: 0.11123998966239539 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9617199843891853, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:49,282] Trial 43 finished with value: 0.1141636608691169 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9768829013816196, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:49,602] Trial 44 finished with value: 0.11424106252785453 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.8687674338663349, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:49,957] Trial 45 finished with value: 0.11950319775953677 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9116371055940551, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:50,348] Trial 46 finished with value: 0.11234311132020629 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9526794969693961, 'max_depth': 5}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:50,683] Trial 47 finished with value: 0.1201717959989874 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.657181130343883, 'max_depth': 3}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:50,955] Trial 48 finished with value: 0.13023767280907173 and parameters: {'min_child_weight': 2, 'gamma': 1, 'subsample': 0.9763561219079617, 'max_depth': 8}. Best is trial 35 with value: 0.10515475152878133.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/1484084565.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.5, 1.0),
# [I 2025-04-05 18:33:51,308] Trial 49 finished with value: 0.11028418818313993 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9474643039473971, 'max_depth': 4}. Best is trial 35 with value: 0.10515475152878133.
# Best RMSE:  0.10515475152878133
# Best Hyperparameters:  {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9957577759157695, 'max_depth': 4}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.9957577759157695, 'max_depth': 4}
xgb_mod = xgb.XGBRegressor(objective = 'reg:squarederror', max_depth = 4, gamma = 0, min_child_weight = 2, 
                           subsample = 0.9957577759157695)
xgb_mod.fit(x_train, y_train)
XGBoost_pred = xgb_mod.predict(x_test)

# %% [markdown]
# ## Step 11: Check for scores

# %%
# Check for the score of the prediction
xgb_mod_score = xgb_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(xgb_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(xgb_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.985
# R Squared:  0.94
# Adjusted R Squared:  0.934
# Mean Squared Error:  0.011
# Root Mean Squared Error:  0.105
# Mean Absolute Error:  0.076
# Accuracy:  89.563 %

# %% [markdown]
# ## Step 12: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 13: Hyperparameter tuning (optuna, with bigger hyperparamter space)

# %%
def objective(trial):
    # Define hyperparameter search space
    parameters = {'objective': 'reg:squarederror',
             'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
             'gamma': trial.suggest_int('gamma', 0.1, 1),
             'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
             'max_depth': trial.suggest_int('max_depth', 1, 20),
             'n_estimators': trial.suggest_int('n_estimators', 100, 1000, step = 100),
             'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
             'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
    # Train xgboost model
    model = xgb.XGBRegressor(**parameters)
    model.fit(x_train, y_train, eval_set = [(x_test, y_test)],  verbose = False)
    # Evaluate model
    predict = model.predict(x_test)
    mse = mean_squared_error(y_test, predict)
    rmse = np.sqrt(mse)
    return rmse

# %%
# Run optuna optimization
study = optuna.create_study(direction = 'minimize')  # Minimize RMSE
study.optimize(objective, n_trials = 50)

# Print best hyperparameters
print('Best RMSE: ', study.best_value)
print('Best Hyperparameters: ', study.best_params)
# Out:
# [I 2025-04-05 18:35:06,399] A new study created in memory with name: no-name-e8ea7537-5f7e-43a1-b176-269a5c29fffe
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:10,897] Trial 0 finished with value: 0.12660415015452942 and parameters: {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.5700588003380276, 'max_depth': 14, 'n_estimators': 1000, 'learning_rate': 0.2250692445014884, 'colsample_bytree': 0.26517502532287673}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:12,731] Trial 1 finished with value: 0.13841085904792513 and parameters: {'min_child_weight': 10, 'gamma': 1, 'subsample': 0.6665114725853621, 'max_depth': 10, 'n_estimators': 800, 'learning_rate': 0.3837012189566666, 'colsample_bytree': 0.46372688911272375}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:13,544] Trial 2 finished with value: 0.18621103501385264 and parameters: {'min_child_weight': 7, 'gamma': 1, 'subsample': 0.4662341315380713, 'max_depth': 15, 'n_estimators': 400, 'learning_rate': 0.9723810776235423, 'colsample_bytree': 0.597606957129702}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:15,430] Trial 3 finished with value: 0.13793970895882818 and parameters: {'min_child_weight': 8, 'gamma': 1, 'subsample': 0.4756879434038811, 'max_depth': 17, 'n_estimators': 1000, 'learning_rate': 0.33817878576632315, 'colsample_bytree': 0.8001225739004479}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:15,753] Trial 4 finished with value: 0.15925083989894598 and parameters: {'min_child_weight': 7, 'gamma': 1, 'subsample': 0.25918818062814825, 'max_depth': 7, 'n_estimators': 100, 'learning_rate': 0.42732446167616706, 'colsample_bytree': 0.7026408457183605}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:16,202] Trial 5 finished with value: 0.14817322291047355 and parameters: {'min_child_weight': 12, 'gamma': 1, 'subsample': 0.9778758926363834, 'max_depth': 7, 'n_estimators': 200, 'learning_rate': 0.595501646072201, 'colsample_bytree': 0.46108901231979216}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:17,369] Trial 6 finished with value: 0.1285941426694033 and parameters: {'min_child_weight': 4, 'gamma': 1, 'subsample': 0.735584852204239, 'max_depth': 14, 'n_estimators': 500, 'learning_rate': 0.06475927843952942, 'colsample_bytree': 0.5221905382692364}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:18,751] Trial 7 finished with value: 0.1920308334629924 and parameters: {'min_child_weight': 17, 'gamma': 1, 'subsample': 0.10318671767721894, 'max_depth': 14, 'n_estimators': 700, 'learning_rate': 0.6178221039584749, 'colsample_bytree': 0.1399179985761323}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:21,195] Trial 8 finished with value: 0.16334896206449304 and parameters: {'min_child_weight': 1, 'gamma': 0, 'subsample': 0.5313624163083971, 'max_depth': 18, 'n_estimators': 800, 'learning_rate': 0.49776874557320344, 'colsample_bytree': 0.6449490979520148}. Best is trial 0 with value: 0.12660415015452942.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:22,900] Trial 9 finished with value: 0.11921615103509732 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.08907594627621171, 'max_depth': 16, 'n_estimators': 500, 'learning_rate': 0.0803177542724687, 'colsample_bytree': 0.1723215322939715}. Best is trial 9 with value: 0.11921615103509732.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:23,755] Trial 10 finished with value: 0.11813829191680679 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.16185411874089894, 'max_depth': 4, 'n_estimators': 300, 'learning_rate': 0.0937132800429678, 'colsample_bytree': 0.11150121413350121}. Best is trial 10 with value: 0.11813829191680679.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:24,373] Trial 11 finished with value: 0.15712625927110363 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.07136624645559357, 'max_depth': 1, 'n_estimators': 300, 'learning_rate': 0.05523153569518821, 'colsample_bytree': 0.036513906299586216}. Best is trial 10 with value: 0.11813829191680679.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:25,353] Trial 12 finished with value: 0.11545995830720404 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.26327976317208535, 'max_depth': 1, 'n_estimators': 500, 'learning_rate': 0.16999233356807564, 'colsample_bytree': 0.28401071224242175}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:25,981] Trial 13 finished with value: 0.11589815558816556 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.30206844127669774, 'max_depth': 1, 'n_estimators': 300, 'learning_rate': 0.2351209994495431, 'colsample_bytree': 0.3109721653581039}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:27,141] Trial 14 finished with value: 0.11690051390449278 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.3164087946567874, 'max_depth': 1, 'n_estimators': 600, 'learning_rate': 0.23552588176920908, 'colsample_bytree': 0.3227701556727317}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:27,495] Trial 15 finished with value: 0.1205693397171378 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.33171131513417096, 'max_depth': 4, 'n_estimators': 100, 'learning_rate': 0.21953551443474661, 'colsample_bytree': 0.9889013057237587}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:28,603] Trial 16 finished with value: 0.550488426472101 and parameters: {'min_child_weight': 14, 'gamma': 0, 'subsample': 0.23720659919703913, 'max_depth': 4, 'n_estimators': 400, 'learning_rate': 0.7362133098755075, 'colsample_bytree': 0.3274103065784981}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:29,703] Trial 17 finished with value: 0.13457374076913117 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.37926601924357517, 'max_depth': 7, 'n_estimators': 300, 'learning_rate': 0.2947509431768451, 'colsample_bytree': 0.4085057913002236}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:32,310] Trial 18 finished with value: 1025.0159752587274 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.22442593796458243, 'max_depth': 11, 'n_estimators': 600, 'learning_rate': 0.8394473893094228, 'colsample_bytree': 0.25517461030090405}. Best is trial 12 with value: 0.11545995830720404.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:33,235] Trial 19 finished with value: 0.11272426134385992 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.8287299464691454, 'max_depth': 2, 'n_estimators': 400, 'learning_rate': 0.16278133974881973, 'colsample_bytree': 0.3725861388816111}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:34,656] Trial 20 finished with value: 0.13404135575603074 and parameters: {'min_child_weight': 12, 'gamma': 0, 'subsample': 0.9225237136395883, 'max_depth': 3, 'n_estimators': 700, 'learning_rate': 0.15658134926962575, 'colsample_bytree': 0.003953744276668225}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:35,461] Trial 21 finished with value: 0.11749253674075232 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.8301363688154544, 'max_depth': 1, 'n_estimators': 400, 'learning_rate': 0.1657278469195875, 'colsample_bytree': 0.36969230993296537}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:36,038] Trial 22 finished with value: 0.133492968398468 and parameters: {'min_child_weight': 18, 'gamma': 0, 'subsample': 0.6450289139078758, 'max_depth': 3, 'n_estimators': 200, 'learning_rate': 0.016834485015522815, 'colsample_bytree': 0.2196365858032488}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:38,825] Trial 23 finished with value: 0.13271666235912785 and parameters: {'min_child_weight': 20, 'gamma': 0, 'subsample': 0.4054761321820277, 'max_depth': 20, 'n_estimators': 500, 'learning_rate': 0.2937377491283974, 'colsample_bytree': 0.39378364126007004}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:40,186] Trial 24 finished with value: 0.13660081004626642 and parameters: {'min_child_weight': 17, 'gamma': 0, 'subsample': 0.7858097116705655, 'max_depth': 6, 'n_estimators': 400, 'learning_rate': 0.4690318660494104, 'colsample_bytree': 0.5574625410117092}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:40,683] Trial 25 finished with value: 0.1332929418638537 and parameters: {'min_child_weight': 19, 'gamma': 0, 'subsample': 0.15860504988409097, 'max_depth': 2, 'n_estimators': 200, 'learning_rate': 0.35825933519255654, 'colsample_bytree': 0.2716478172427792}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:43,198] Trial 26 finished with value: 0.11471706939228078 and parameters: {'min_child_weight': 16, 'gamma': 0, 'subsample': 0.5975812217380168, 'max_depth': 10, 'n_estimators': 600, 'learning_rate': 0.15048214441139263, 'colsample_bytree': 0.10339087311702708}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:46,309] Trial 27 finished with value: 0.12231920213639176 and parameters: {'min_child_weight': 15, 'gamma': 0, 'subsample': 0.8661427714665482, 'max_depth': 11, 'n_estimators': 700, 'learning_rate': 0.16546322038019096, 'colsample_bytree': 0.08939050332155049}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:48,804] Trial 28 finished with value: 0.11310845810752669 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.6236324609339667, 'max_depth': 9, 'n_estimators': 600, 'learning_rate': 0.1366502949677929, 'colsample_bytree': 0.16654043024058574}. Best is trial 19 with value: 0.11272426134385992.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:54,568] Trial 29 finished with value: 0.11234134869830169 and parameters: {'min_child_weight': 12, 'gamma': 0, 'subsample': 0.6386974083461762, 'max_depth': 9, 'n_estimators': 900, 'learning_rate': 0.12801015056677217, 'colsample_bytree': 0.19534228322084657}. Best is trial 29 with value: 0.11234134869830169.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:35:58,222] Trial 30 finished with value: 0.15889990788972394 and parameters: {'min_child_weight': 10, 'gamma': 0, 'subsample': 0.6877680821648122, 'max_depth': 9, 'n_estimators': 1000, 'learning_rate': 0.5551780283712768, 'colsample_bytree': 0.17849134572543224}. Best is trial 29 with value: 0.11234134869830169.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:02,421] Trial 31 finished with value: 0.11983118503608726 and parameters: {'min_child_weight': 13, 'gamma': 0, 'subsample': 0.6099826978205478, 'max_depth': 12, 'n_estimators': 900, 'learning_rate': 0.1263514524696866, 'colsample_bytree': 0.062195951863534035}. Best is trial 29 with value: 0.11234134869830169.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:05,582] Trial 32 finished with value: 0.10641390417851991 and parameters: {'min_child_weight': 11, 'gamma': 0, 'subsample': 0.5792194911173331, 'max_depth': 9, 'n_estimators': 800, 'learning_rate': 0.023582480194517322, 'colsample_bytree': 0.20055927521605985}. Best is trial 32 with value: 0.10641390417851991.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:09,333] Trial 33 finished with value: 0.1054033708057181 and parameters: {'min_child_weight': 9, 'gamma': 0, 'subsample': 0.713990738119916, 'max_depth': 9, 'n_estimators': 900, 'learning_rate': 0.018356658119262306, 'colsample_bytree': 0.21074793689578822}. Best is trial 33 with value: 0.1054033708057181.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:12,828] Trial 34 finished with value: 0.10500903526812895 and parameters: {'min_child_weight': 9, 'gamma': 0, 'subsample': 0.7265013600527372, 'max_depth': 8, 'n_estimators': 900, 'learning_rate': 0.019112634844250374, 'colsample_bytree': 0.24042075635048715}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# ...
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:23,313] Trial 38 finished with value: 0.126636859690826 and parameters: {'min_child_weight': 5, 'gamma': 1, 'subsample': 0.6965732961737745, 'max_depth': 12, 'n_estimators': 1000, 'learning_rate': 0.01737303577227324, 'colsample_bytree': 0.2435141873866935}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:25,469] Trial 39 finished with value: 0.21454669735605753 and parameters: {'min_child_weight': 5, 'gamma': 0, 'subsample': 0.7256022103832113, 'max_depth': 7, 'n_estimators': 800, 'learning_rate': 0.9930338240842049, 'colsample_bytree': 0.8341428607636346}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:27,136] Trial 40 finished with value: 0.12837405645966682 and parameters: {'min_child_weight': 8, 'gamma': 1, 'subsample': 0.7577434392905468, 'max_depth': 8, 'n_estimators': 900, 'learning_rate': 0.0884801053191438, 'colsample_bytree': 0.4257407012010784}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:30,122] Trial 41 finished with value: 0.10522339965343212 and parameters: {'min_child_weight': 9, 'gamma': 0, 'subsample': 0.4813443165147075, 'max_depth': 8, 'n_estimators': 800, 'learning_rate': 0.019055228947039475, 'colsample_bytree': 0.20783320864477198}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:32,748] Trial 42 finished with value: 0.11000699316257657 and parameters: {'min_child_weight': 6, 'gamma': 0, 'subsample': 0.47106286842788686, 'max_depth': 6, 'n_estimators': 800, 'learning_rate': 0.08019799262107982, 'colsample_bytree': 0.13628671408723347}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:36,875] Trial 43 finished with value: 0.10705160977232148 and parameters: {'min_child_weight': 2, 'gamma': 0, 'subsample': 0.5135451487037811, 'max_depth': 8, 'n_estimators': 1000, 'learning_rate': 0.07273771350549765, 'colsample_bytree': 0.22364357473976587}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:40,294] Trial 44 finished with value: 0.12053508343646115 and parameters: {'min_child_weight': 8, 'gamma': 0, 'subsample': 0.423308353208005, 'max_depth': 8, 'n_estimators': 900, 'learning_rate': 0.20590266824014902, 'colsample_bytree': 0.33351427422163504}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:44,436] Trial 45 finished with value: 0.10757148230015076 and parameters: {'min_child_weight': 9, 'gamma': 0, 'subsample': 0.5475572782421725, 'max_depth': 13, 'n_estimators': 800, 'learning_rate': 0.010599853058350716, 'colsample_bytree': 0.2749985851221277}. Best is trial 34 with value: 0.10500903526812895.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:46,524] Trial 46 finished with value: 0.10434952810611312 and parameters: {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.7758602038324858, 'max_depth': 5, 'n_estimators': 700, 'learning_rate': 0.10482730727478165, 'colsample_bytree': 0.14336342365439678}. Best is trial 46 with value: 0.10434952810611312.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:48,532] Trial 47 finished with value: 0.1053844739626396 and parameters: {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.9738510626866613, 'max_depth': 5, 'n_estimators': 700, 'learning_rate': 0.1056727469347051, 'colsample_bytree': 0.04974073991367789}. Best is trial 46 with value: 0.10434952810611312.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:49,999] Trial 48 finished with value: 0.13973938074174874 and parameters: {'min_child_weight': 3, 'gamma': 0, 'subsample': 0.9727658417124528, 'max_depth': 5, 'n_estimators': 700, 'learning_rate': 0.2777093429195488, 'colsample_bytree': 0.0019821148953169387}. Best is trial 46 with value: 0.10434952810611312.
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:6: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'subsample': trial.suggest_uniform('subsample', 0.05, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:9: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'learning_rate': trial.suggest_uniform('learning_rate', 0.01, 1.0),
# /var/folders/bc/6ybxr1xs1f98kjg2pl98nqlc0000gn/T/ipykernel_56781/3491079507.py:10: FutureWarning: suggest_uniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float instead.
#   'colsample_bytree': trial.suggest_uniform('colsample_bytree', 0, 1.0)}
# [I 2025-04-05 18:36:52,020] Trial 49 finished with value: 0.10352359474768445 and parameters: {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.9170665228361083, 'max_depth': 5, 'n_estimators': 700, 'learning_rate': 0.10377602456854357, 'colsample_bytree': 0.13699095111031812}. Best is trial 49 with value: 0.10352359474768445.
# Best RMSE:  0.10352359474768445
# Best Hyperparameters:  {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.9170665228361083, 'max_depth': 5, 'n_estimators': 700, 'learning_rate': 0.10377602456854357, 'colsample_bytree': 0.13699095111031812}

# %%
# Built a XGBoost model with the new hyperparameter option
# {'min_child_weight': 7, 'gamma': 0, 'subsample': 0.9170665228361083, 'max_depth': 5, 'n_estimators': 700, 
# 'learning_rate': 0.10377602456854357, 'colsample_bytree': 0.13699095111031812}
xgboost_mod = xgb.XGBRegressor(objective = 'reg:squarederror', min_child_weight = 7, gamma = 0, 
                               subsample = 0.9170665228361083, max_depth = 5, n_estimators = 700, 
                               learning_rate = 0.10377602456854357, colsample_bytree = 0.13699095111031812)
xgboost_mod.fit(x_train, y_train)
XGBoost_pred = xgboost_mod.predict(x_test)

# %% [markdown]
# ## Step 14: Check for scores

# %%
# Check for the score of the prediction
xgboost_mod_score = xgboost_mod.score(x_train, y_train)
print('XGBoost Model Score: ', round(xgboost_mod_score, 3))

# R squared value
r2 = r2_score(y_test, XGBoost_pred)
print('R Squared: ', round(r2, 3))

# Adjusted R squared value
adj_r2 = 1 - (1 - r2) * (len(y) - 1) / (len(y) - x.shape[1] - 1)
print('Adjusted R Squared: ', round(adj_r2, 3))

# Mean squared error
mean_sq = mean_squared_error(y_test, XGBoost_pred)
print('Mean Squared Error: ', round(mean_sq, 3))

# Root mean squared error
root_mean_sq = np.sqrt(mean_sq)
print('Root Mean Squared Error: ', round(root_mean_sq, 3))

# Mean absolute error
mean_ab = mean_absolute_error(y_test, XGBoost_pred)
print('Mean Absolute Error: ', round(mean_ab, 3))

# Cross validation (or accuracy)
cv = cross_val_score(xgboost_mod, x, y, scoring = 'r2', cv = 5)
print('Accuracy: ', round(cv.mean() * 100, 3), '%')
# Out:
# XGBoost Model Score:  0.996
# R Squared:  0.942
# Adjusted R Squared:  0.936
# Mean Squared Error:  0.011
# Root Mean Squared Error:  0.104
# Mean Absolute Error:  0.072
# Accuracy:  90.807 %

# %% [markdown]
# ## Step 15: Create visuals

# %%
actual_price = np.expm1(y_test)
predicted_price = np.expm1(XGBoost_pred)

# Create a scatter plot
plt.scatter(actual_price, predicted_price, c = 'crimson')

# Draw the line of perfect prediction (where actual = predicted)
p1 = max(max(predicted_price), max(actual_price))
p2 = min(min(predicted_price), min(actual_price))
plt.plot([p1, p2], [p1, p2], 'b-')

# Add labels
plt.xlabel('Actual Values', fontsize = 15)
plt.ylabel('Predicted Values', fontsize = 15)

# Make sure the axes are scaled equally
plt.axis('equal')

plt.show()

# %%
# Distribution of residuals (difference between actual and predicted value)
sb.displot((y_test - XGBoost_pred), bins = 100, kde = True)

# %% [markdown]
# ## Step 16: Check feature important

# %%
feature_important = xgboost_mod.get_booster().get_score(importance_type = 'total_gain')
# Extract the feature names and scores
keys = list(feature_important.keys())
values = list(feature_important.values())
# Create a dataframe
data = pd.DataFrame(data = values, index = keys, columns = ['score']).sort_values(by = 'score', ascending = True)
# Plot the top 10 features
data.nlargest(10, columns = 'score').plot(kind = 'barh', figsize = (10, 15))
# Out:
# <Axes: >
